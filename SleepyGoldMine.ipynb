# %% [markdown]
# # Welcome to Sleepy's Gold Mine

# %% [markdown]
# ![au.jpeg](attachment:au.jpeg)

# %%
import numpy as np
print("Learn how much would your investment in gold be worth today")
n = input("Enter Year Here (1900-2020): ")
n = int(n)
currentyear = 2021
if n < 1900 or n >= currentyear:
    print("The year entered was not in between 1900 and 2020")
else:
    offset = currentyear-n
                #print(ray[x])
    ray = [1804.83, 1773.73, 1393.34,1268.93,1260.39,1251.92,1158.86,1266.06,1409.51,1668.86,1573.16,1226.66,973.66,872.37,696.43,604.34,444.99,409.53,363.83,310.08,271.19,279.29,278.86,294.12,331.00,387.73,384.07,384.16,360.05,343.87,362.34,383.73,381.27,436.78,446.84,368.20,317.42,360.65,423.71,376.11,459.16,614.75,307.01,193.57,147.84,124.80,160.87,158.76,97.12,58.17,40.80,35.96,41.10,35.94,35.94,35.94,35.12,35.12,35.12,35.12,35.12,35.27,35.27,35.27,35.27,35.27,35.03,35.03,35.03,35.03,35.03,34.72,34.72,34.72,34.72,34.72,34.72,34.72,34.72,34.72,34.72,33.85,33.85,33.85,33.85,33.85,33.85,33.85,33.85,33.85,33.85,20.65,20.65,20.65,20.65,20.65,20.65,20.65,20.65,20.65, 20.65, 20.68, 20.68, 20.68, 20.68, 20.68, 20.68, 20.68, 20.68, 20.68, 20.68, 20.64, 20.64, 20.64, 20.64, 20.64, 20.64, 20.64, 20.64, 20.64, 20.64, 20.64]
    rate = np.exp((np.log(ray[0]/ray[offset]))/offset)
                #print(rate)
    y = (rate)**offset
    y = int(y)
    
                #print(y)
    
    print("If you invested a $20 Bill in gold in",n,"and reinvested your earnings each year, it would be worth"
                  , y, "$20 bills today")
# Out:
# Learn how much would your investment in gold be worth today
# Enter Year Here (1900-2020): 1999
# If you invested a $20 Bill in gold in 1999 and reinvested your earnings each year, it would be worth 6 $20 bills today
